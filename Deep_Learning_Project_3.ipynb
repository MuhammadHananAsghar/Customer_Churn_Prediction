# %% [markdown]
# ##Customer Churn Prediction

# %% [markdown]
# `Dataset:`https://www.kaggle.com/blastchar/telco-customer-churn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("/content/WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0  7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1  5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2  3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3  7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4  9237-HQITU  Female              0  ...          70.70       151.65    Yes
#
# [5 rows x 21 columns]

# %%
df.drop('customerID',axis='columns', inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 0  Female              0     Yes  ...          29.85         29.85    No
# 1    Male              0      No  ...          56.95        1889.5    No
# 2    Male              0      No  ...          53.85        108.15   Yes
# 3    Male              0      No  ...          42.30       1840.75    No
# 4  Female              0      No  ...          70.70        151.65   Yes
#
# [5 rows x 20 columns]

# %%
pd.to_numeric(df.TotalCharges, errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges, errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner  ... MonthlyCharges  TotalCharges Churn
# 488   Female              0     Yes  ...          52.55                  No
# 753     Male              0      No  ...          20.25                  No
# 936   Female              0     Yes  ...          80.85                  No
# 1082    Male              0     Yes  ...          25.75                  No
# 1340  Female              0     Yes  ...          56.05                  No
# 3331    Male              0     Yes  ...          19.85                  No
# 3826    Male              0     Yes  ...          25.35                  No
# 4380  Female              0     Yes  ...          20.00                  No
# 5218    Male              0     Yes  ...          19.70                  No
# 6670  Female              0     Yes  ...          73.35                  No
# 6754    Male              0      No  ...          61.90                  No
#
# [11 rows x 20 columns]

# %%
df1 = df[df.TotalCharges != ' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.dtype
# Out:
# dtype('float64')

# %%
tenure_churn_no = df1[df1.Churn == 'No'].tenure
tenure_churn_yes = df1[df1.Churn == 'Yes'].tenure

# %%
plt.hist([tenure_churn_yes, tenure_churn_no], color=['green', 'red'], label=['Churn=Yes', 'Churn=No'])
plt.xlabel('Tenure')
plt.ylabel('Number of Customers')
plt.title('Customer Churn Prediction Visualization')
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
df1.replace('No internet service', 'No', inplace=True)

# %%
df1.replace('No phone service', 'No', inplace=True)

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
df1.head()
# Out:
#    gender  SeniorCitizen  Partner  ...  MonthlyCharges  TotalCharges  Churn
# 0  Female              0        1  ...           29.85         29.85      0
# 1    Male              0        0  ...           56.95       1889.50      0
# 2    Male              0        0  ...           53.85        108.15      1
# 3    Male              0        0  ...           42.30       1840.75      0
# 4  Female              0        0  ...           70.70        151.65      1
#
# [5 rows x 20 columns]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.head()
# Out:
#    gender  ...  PaymentMethod_Mailed check
# 0       1  ...                           0
# 1       0  ...                           1
# 2       0  ...                           1
# 3       0  ...                           0
# 4       1  ...                           0
#
# [5 rows x 27 columns]

# %%
df2.sample(5)
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 6547       0  ...                           0
# 3785       0  ...                           0
# 4542       1  ...                           1
# 143        0  ...                           0
# 1928       1  ...                           1
#
# [5 rows x 27 columns]

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# InternetService_No                           uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# Contract_Two year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# PaymentMethod_Mailed check                   uint8
# dtype: object

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [0.11542289 0.38507463 0.35422886 ... 0.44626866 0.25820896 0.60149254]
# TotalCharges: [0.0012751  0.21586661 0.01031041 ... 0.03780868 0.03321025 0.78764136]
# Churn: [0 1]
# InternetService_DSL: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_Month-to-month: [1 0]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Bank transfer (automatic): [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %%
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
X_test.shape
X_train[:10]
# Out:
#       gender  ...  PaymentMethod_Mailed check
# 5664       1  ...                           0
# 101        1  ...                           0
# 2621       0  ...                           0
# 392        1  ...                           0
# 1327       0  ...                           0
# 3607       1  ...                           1
# 2773       0  ...                           0
# 1936       1  ...                           0
# 5387       0  ...                           0
# 4331       0  ...                           0
#
# [10 rows x 26 columns]

# %% [markdown]
# Build a model (ANN)

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(26, input_shape=(26,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 1ms/step - loss: 0.5614 - accuracy: 0.7470
# Epoch 2/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4378 - accuracy: 0.7904
# Epoch 3/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4191 - accuracy: 0.8030
# Epoch 4/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4038 - accuracy: 0.8079
# Epoch 5/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8024
# Epoch 6/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8004
# Epoch 7/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4095 - accuracy: 0.8071
# Epoch 8/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4123 - accuracy: 0.8034
# Epoch 9/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8016
# Epoch 10/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8203
# Epoch 11/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.8023
# Epoch 12/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.8171
# Epoch 13/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8123
# Epoch 14/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4061 - accuracy: 0.8168
# Epoch 15/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3990 - accuracy: 0.8080
# Epoch 16/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4197 - accuracy: 0.8056
# Epoch 17/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4004 - accuracy: 0.8162
# Epoch 18/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.8156
# Epoch 19/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8166
# Epoch 20/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3937 - accuracy: 0.8169
# Epoch 21/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8159
# Epoch 22/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3867 - accuracy: 0.8181
# Epoch 23/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8158
# Epoch 24/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3928 - accuracy: 0.8133
# Epoch 25/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3873 - accuracy: 0.8190
# Epoch 26/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8184
# Epoch 27/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3925 - accuracy: 0.8172
# Epoch 28/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8174
# Epoch 29/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3884 - accuracy: 0.8207
# Epoch 30/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.8196
# Epoch 31/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3916 - accuracy: 0.8141
# Epoch 32/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.4006 - accuracy: 0.8081
# Epoch 33/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3807 - accuracy: 0.8157
# Epoch 34/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3781 - accuracy: 0.8256
# Epoch 35/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8096
# Epoch 36/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3836 - accuracy: 0.8212
# Epoch 37/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8257
# Epoch 38/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3912 - accuracy: 0.8119
# Epoch 39/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3868 - accuracy: 0.8179
# Epoch 40/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3853 - accuracy: 0.8215
# Epoch 41/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3787 - accuracy: 0.8176
# Epoch 42/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3904 - accuracy: 0.8128
# Epoch 43/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.8270
# Epoch 44/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3851 - accuracy: 0.8188
# Epoch 45/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3829 - accuracy: 0.8195
# Epoch 46/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3796 - accuracy: 0.8224
# Epoch 47/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.8220
# Epoch 48/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3700 - accuracy: 0.8299
# Epoch 49/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3789 - accuracy: 0.8224
# Epoch 50/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3673 - accuracy: 0.8351
# Epoch 51/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3769 - accuracy: 0.8228
# Epoch 52/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8267
# Epoch 53/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3835 - accuracy: 0.8243
# Epoch 54/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3851 - accuracy: 0.8137
# Epoch 55/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3811 - accuracy: 0.8172
# Epoch 56/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3694 - accuracy: 0.8272
# Epoch 57/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3542 - accuracy: 0.8378
# Epoch 58/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3544 - accuracy: 0.8368
# Epoch 59/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3598 - accuracy: 0.8328
# Epoch 60/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3610 - accuracy: 0.8271
# Epoch 61/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3724 - accuracy: 0.8268
# Epoch 62/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3574 - accuracy: 0.8306
# Epoch 63/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3789 - accuracy: 0.8235
# Epoch 64/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8275
# Epoch 65/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8238
# Epoch 66/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3631 - accuracy: 0.8281
# Epoch 67/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3695 - accuracy: 0.8258
# Epoch 68/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3691 - accuracy: 0.8252
# Epoch 69/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8233
# Epoch 70/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3660 - accuracy: 0.8327
# Epoch 71/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3664 - accuracy: 0.8267
# Epoch 72/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3678 - accuracy: 0.8304
# Epoch 73/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3654 - accuracy: 0.8304
# Epoch 74/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3782 - accuracy: 0.8226
# Epoch 75/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3727 - accuracy: 0.8221
# Epoch 76/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8387
# Epoch 77/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3566 - accuracy: 0.8406
# Epoch 78/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3523 - accuracy: 0.8362
# Epoch 79/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.8313
# Epoch 80/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3467 - accuracy: 0.8383
# Epoch 81/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3570 - accuracy: 0.8348
# Epoch 82/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3590 - accuracy: 0.8389
# Epoch 83/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3662 - accuracy: 0.8322
# Epoch 84/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3506 - accuracy: 0.8410
# Epoch 85/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3471 - accuracy: 0.8401
# Epoch 86/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8394
# Epoch 87/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8381
# Epoch 88/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3601 - accuracy: 0.8365
# Epoch 89/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3609 - accuracy: 0.8308
# Epoch 90/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3388 - accuracy: 0.8358
# Epoch 91/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3547 - accuracy: 0.8294
# Epoch 92/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3465 - accuracy: 0.8369
# Epoch 93/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3558 - accuracy: 0.8287
# Epoch 94/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8320
# Epoch 95/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8330
# Epoch 96/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3470 - accuracy: 0.8343
# Epoch 97/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3448 - accuracy: 0.8474
# Epoch 98/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8411
# Epoch 99/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8283
# Epoch 100/100
# 176/176 [==============================] - 0s 1ms/step - loss: 0.3306 - accuracy: 0.8489

# %%
model.evaluate(X_test, y_test)
# Out:
# 44/44 [==============================] - 0s 1ms/step - loss: 0.4743 - accuracy: 0.7790
# [0.4742923974990845, 0.7789623141288757]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[0.13377455],
#        [0.28263527],
#        [0.0011431 ],
#        [0.7397733 ],
#        [0.48735723]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 0, 0, 1, 0, 1, 0, 0, 0, 0]

# %%
y_test[:10]
# Out:
# 2660    0
# 744     0
# 5579    1
# 64      1
# 3287    1
# 816     1
# 2670    0
# 5920    0
# 1023    0
# 6087    0
# Name: Churn, dtype: int64

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
